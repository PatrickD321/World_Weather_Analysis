# %%
# import dependencies.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Import the request library.
import requests

# Import the API key.
from config import weather_api_keys
# weather_api_keys

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9d8f7c112632932f862961cceb1956eb

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations 2.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# 6.1 Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_description = city_weather["weather"][0]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Current Description": city_description,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | antalaha
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | norfolk
# Processing Record 4 of Set 1 | nhulunbuy
# Processing Record 5 of Set 1 | la rioja
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | lingao
# Processing Record 10 of Set 1 | skalnyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | talara
# Processing Record 16 of Set 1 | caravelas
# Processing Record 17 of Set 1 | matveyevka
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | tessalit
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | cangzhou
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | celestun
# Processing Record 29 of Set 1 | yulara
# Processing Record 30 of Set 1 | burica
# City not found. Skipping...
# Processing Record 31 of Set 1 | santana do livramento
# Processing Record 32 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 1 | araouane
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | erzin
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | la paz
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | kostyantynivka
# Processing Record 41 of Set 1 | husavik
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | loa janan
# Processing Record 45 of Set 1 | hami
# Processing Record 46 of Set 1 | puerto quijarro
# Processing Record 47 of Set 1 | tricase
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | lhokseumawe
# Processing Record 50 of Set 1 | lorengau
# Processing Record 1 of Set 2 | evensk
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | bontang
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | girne
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | zhanakorgan
# Processing Record 10 of Set 2 | tilichiki
# Processing Record 11 of Set 2 | bubaque
# Processing Record 12 of Set 2 | gravdal
# Processing Record 13 of Set 2 | valparaiso
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | santa luzia
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | goma
# Processing Record 18 of Set 2 | fare
# Processing Record 19 of Set 2 | aviles
# Processing Record 20 of Set 2 | barra dos coqueiros
# Processing Record 21 of Set 2 | maniitsoq
# Processing Record 22 of Set 2 | idlib
# Processing Record 23 of Set 2 | puerto plata
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | coihaique
# Processing Record 28 of Set 2 | itoman
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | mecca
# Processing Record 31 of Set 2 | mount isa
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | sabang
# Processing Record 35 of Set 2 | mogadishu
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | makrisia
# Processing Record 39 of Set 2 | erenhot
# Processing Record 40 of Set 2 | rocha
# Processing Record 41 of Set 2 | dudinka
# Processing Record 42 of Set 2 | lata
# Processing Record 43 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | sibolga
# Processing Record 46 of Set 2 | constantine
# Processing Record 47 of Set 2 | kontagora
# Processing Record 48 of Set 2 | imbituba
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | jaciara
# Processing Record 1 of Set 3 | asau
# Processing Record 2 of Set 3 | coruripe
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | myre
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | yerofey pavlovich
# Processing Record 8 of Set 3 | outjo
# Processing Record 9 of Set 3 | santa cruz
# Processing Record 10 of Set 3 | provideniya
# Processing Record 11 of Set 3 | zemio
# Processing Record 12 of Set 3 | katangli
# Processing Record 13 of Set 3 | port macquarie
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | ostrovnoy
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | progreso
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | ostrowiec swietokrzyski
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | campana
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | najran
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | floro
# Processing Record 26 of Set 3 | vestmannaeyjar
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | saint-augustin
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | san patricio
# Processing Record 34 of Set 3 | shirakamut
# Processing Record 35 of Set 3 | ambon
# Processing Record 36 of Set 3 | tura
# Processing Record 37 of Set 3 | santa cruz de tenerife
# Processing Record 38 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | oda
# Processing Record 41 of Set 3 | baykit
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | kysyl-syr
# Processing Record 44 of Set 3 | kilindoni
# Processing Record 45 of Set 3 | ortona
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | keningau
# Processing Record 48 of Set 3 | cape town
# Processing Record 49 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | dulovo
# Processing Record 2 of Set 4 | marsh harbour
# Processing Record 3 of Set 4 | high level
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | nantucket
# Processing Record 6 of Set 4 | las vegas
# Processing Record 7 of Set 4 | jati
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | namibe
# Processing Record 13 of Set 4 | santa fe
# Processing Record 14 of Set 4 | shiyan
# Processing Record 15 of Set 4 | porto novo
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | muromtsevo
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | saint-pierre
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | basco
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | waki
# Processing Record 27 of Set 4 | sirari
# Processing Record 28 of Set 4 | pyshma
# Processing Record 29 of Set 4 | gushikawa
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | touros
# Processing Record 32 of Set 4 | maceio
# Processing Record 33 of Set 4 | san jeronimo
# Processing Record 34 of Set 4 | marienburg
# Processing Record 35 of Set 4 | christiana
# Processing Record 36 of Set 4 | morro bay
# Processing Record 37 of Set 4 | vestmanna
# Processing Record 38 of Set 4 | mohanur
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | svetlogorsk
# Processing Record 41 of Set 4 | mugur-aksy
# Processing Record 42 of Set 4 | jalu
# Processing Record 43 of Set 4 | banjar
# Processing Record 44 of Set 4 | louviers
# Processing Record 45 of Set 4 | sogne
# Processing Record 46 of Set 4 | axim
# Processing Record 47 of Set 4 | alekseyevsk
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | kiruna
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | general roca
# Processing Record 4 of Set 5 | bestobe
# Processing Record 5 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 5 | murighiol
# Processing Record 7 of Set 5 | ambikapur
# Processing Record 8 of Set 5 | antofagasta
# Processing Record 9 of Set 5 | tilsonburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | saint-honore
# Processing Record 11 of Set 5 | hithadhoo
# Processing Record 12 of Set 5 | muros
# Processing Record 13 of Set 5 | barrow
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 5 | tabory
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | vezirkopru
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | myitkyina
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | khash
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | buritis
# Processing Record 29 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 5 | shingu
# Processing Record 31 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 5 | kosh-agach
# Processing Record 33 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | dolny kubin
# Processing Record 36 of Set 5 | chaplynka
# Processing Record 37 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 5 | pemangkat
# Processing Record 39 of Set 5 | matamoros
# Processing Record 40 of Set 5 | qingdao
# Processing Record 41 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 5 | anadyr
# Processing Record 43 of Set 5 | zempoala
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | leszno
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | urengoy
# Processing Record 48 of Set 5 | umm lajj
# Processing Record 49 of Set 5 | beloha
# Processing Record 50 of Set 5 | poum
# Processing Record 1 of Set 6 | arman
# Processing Record 2 of Set 6 | walvis bay
# Processing Record 3 of Set 6 | kanniyakumari
# Processing Record 4 of Set 6 | jaru
# Processing Record 5 of Set 6 | lodja
# Processing Record 6 of Set 6 | sydney
# Processing Record 7 of Set 6 | kerouane
# Processing Record 8 of Set 6 | sinop
# Processing Record 9 of Set 6 | samarai
# Processing Record 10 of Set 6 | rudnya
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | manicore
# Processing Record 13 of Set 6 | wattegama
# Processing Record 14 of Set 6 | wonthaggi
# Processing Record 15 of Set 6 | pudozh
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | pleshanovo
# Processing Record 18 of Set 6 | olafsvik
# Processing Record 19 of Set 6 | quetzaltepec
# City not found. Skipping...
# Processing Record 20 of Set 6 | baker city
# Processing Record 21 of Set 6 | acarau
# Processing Record 22 of Set 6 | hailey
# Processing Record 23 of Set 6 | esperance
# Processing Record 24 of Set 6 | peiting
# Processing Record 25 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 6 | maltahohe
# Processing Record 27 of Set 6 | talah
# City not found. Skipping...
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | oum hadjer
# Processing Record 30 of Set 6 | ahipara
# Processing Record 31 of Set 6 | mirnyy
# Processing Record 32 of Set 6 | tucuman
# Processing Record 33 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | yerbogachen
# Processing Record 36 of Set 6 | asyut
# Processing Record 37 of Set 6 | chapada dos guimaraes
# Processing Record 38 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 6 | theunissen
# Processing Record 40 of Set 6 | inhambane
# Processing Record 41 of Set 6 | geraldton
# Processing Record 42 of Set 6 | malgrat de mar
# Processing Record 43 of Set 6 | ilabaya
# Processing Record 44 of Set 6 | kaitangata
# Processing Record 45 of Set 6 | balakhninskiy
# Processing Record 46 of Set 6 | kangaatsiaq
# Processing Record 47 of Set 6 | pacific grove
# Processing Record 48 of Set 6 | saint-philippe
# Processing Record 49 of Set 6 | karaton
# Processing Record 50 of Set 6 | koumac
# Processing Record 1 of Set 7 | byron bay
# Processing Record 2 of Set 7 | arawa
# Processing Record 3 of Set 7 | sao jose da coroa grande
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | krasnoselkup
# Processing Record 6 of Set 7 | darab
# Processing Record 7 of Set 7 | bonthe
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | tirukkoyilur
# Processing Record 10 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 7 | magistralnyy
# Processing Record 12 of Set 7 | hay river
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | aurillac
# Processing Record 15 of Set 7 | chandbali
# Processing Record 16 of Set 7 | salvador
# Processing Record 17 of Set 7 | klaksvik
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | puerto escondido
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | wangdiphodrang
# City not found. Skipping...
# Processing Record 22 of Set 7 | khandbari
# Processing Record 23 of Set 7 | ranavav
# Processing Record 24 of Set 7 | severo-yeniseyskiy
# Processing Record 25 of Set 7 | mamakan
# Processing Record 26 of Set 7 | bo phloi
# Processing Record 27 of Set 7 | abu kamal
# Processing Record 28 of Set 7 | nishihara
# Processing Record 29 of Set 7 | zhezkazgan
# Processing Record 30 of Set 7 | upington
# Processing Record 31 of Set 7 | beatrice
# Processing Record 32 of Set 7 | collie
# Processing Record 33 of Set 7 | suluq
# Processing Record 34 of Set 7 | bethel
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | otradnoye
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | muli
# Processing Record 39 of Set 7 | paamiut
# Processing Record 40 of Set 7 | aljezur
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | hovd
# Processing Record 43 of Set 7 | airai
# Processing Record 44 of Set 7 | sao filipe
# Processing Record 45 of Set 7 | raymondville
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | cherskiy
# Processing Record 48 of Set 7 | masuguru
# Processing Record 49 of Set 7 | passagem franca
# Processing Record 50 of Set 7 | la palma
# Processing Record 1 of Set 8 | zyryanka
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | spolaita
# Processing Record 4 of Set 8 | sarbogard
# Processing Record 5 of Set 8 | conde
# Processing Record 6 of Set 8 | homa bay
# Processing Record 7 of Set 8 | road town
# Processing Record 8 of Set 8 | hasaki
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | tanushimaru
# Processing Record 11 of Set 8 | eyl
# Processing Record 12 of Set 8 | arraial do cabo
# Processing Record 13 of Set 8 | oranjestad
# Processing Record 14 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 15 of Set 8 | matara
# Processing Record 16 of Set 8 | dutse
# Processing Record 17 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 8 | methoni
# Processing Record 19 of Set 8 | payson
# Processing Record 20 of Set 8 | panotla
# Processing Record 21 of Set 8 | rosarito
# Processing Record 22 of Set 8 | beipiao
# Processing Record 23 of Set 8 | jinka
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | seremban
# Processing Record 26 of Set 8 | katherine
# Processing Record 27 of Set 8 | suntar
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | montepuez
# Processing Record 30 of Set 8 | pachperwa
# Processing Record 31 of Set 8 | teguldet
# Processing Record 32 of Set 8 | pizarro
# Processing Record 33 of Set 8 | gap
# Processing Record 34 of Set 8 | pokrovka
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | padang
# Processing Record 37 of Set 8 | batagay
# Processing Record 38 of Set 8 | bayanday
# Processing Record 39 of Set 8 | villacarrillo
# Processing Record 40 of Set 8 | bilibino
# Processing Record 41 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 8 | seddon
# Processing Record 43 of Set 8 | arriaga
# Processing Record 44 of Set 8 | pevek
# Processing Record 45 of Set 8 | sault sainte marie
# Processing Record 46 of Set 8 | sambava
# Processing Record 47 of Set 8 | severo-kurilsk
# Processing Record 48 of Set 8 | chumikan
# Processing Record 49 of Set 8 | nadym
# Processing Record 50 of Set 8 | lichuan
# Processing Record 1 of Set 9 | kaeo
# Processing Record 2 of Set 9 | metro
# Processing Record 3 of Set 9 | popondetta
# Processing Record 4 of Set 9 | tuatapere
# Processing Record 5 of Set 9 | altay
# Processing Record 6 of Set 9 | lokoja
# Processing Record 7 of Set 9 | ribeira grande
# Processing Record 8 of Set 9 | kovdor
# Processing Record 9 of Set 9 | dzilam gonzalez
# Processing Record 10 of Set 9 | katsuura
# Processing Record 11 of Set 9 | kloulklubed
# Processing Record 12 of Set 9 | pisco
# Processing Record 13 of Set 9 | iqaluit
# Processing Record 14 of Set 9 | huntsville
# Processing Record 15 of Set 9 | mazatlan
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 18 of Set 9 | hefei
# Processing Record 19 of Set 9 | pelotas
# Processing Record 20 of Set 9 | santo antonio do leverger
# Processing Record 21 of Set 9 | muravlenko
# Processing Record 22 of Set 9 | calama
# Processing Record 23 of Set 9 | caxias
# Processing Record 24 of Set 9 | taltal
# Processing Record 25 of Set 9 | shelburne
# Processing Record 26 of Set 9 | pochutla
# Processing Record 27 of Set 9 | doctor arroyo
# Processing Record 28 of Set 9 | dawlatabad
# Processing Record 29 of Set 9 | privas
# Processing Record 30 of Set 9 | boueni
# Processing Record 31 of Set 9 | mapiripan
# Processing Record 32 of Set 9 | sorada
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | duvan
# Processing Record 35 of Set 9 | kearney
# Processing Record 36 of Set 9 | aliwal north
# Processing Record 37 of Set 9 | buraydah
# Processing Record 38 of Set 9 | nuevo laredo
# Processing Record 39 of Set 9 | kemijarvi
# Processing Record 40 of Set 9 | luderitz
# Processing Record 41 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 42 of Set 9 | amudat
# Processing Record 43 of Set 9 | warrnambool
# Processing Record 44 of Set 9 | santona
# Processing Record 45 of Set 9 | kalga
# Processing Record 46 of Set 9 | norman wells
# Processing Record 47 of Set 9 | mallama
# City not found. Skipping...
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | skalat
# Processing Record 50 of Set 9 | kabare
# Processing Record 1 of Set 10 | anuppur
# Processing Record 2 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 10 | sol-iletsk
# Processing Record 4 of Set 10 | merauke
# Processing Record 5 of Set 10 | elko
# Processing Record 6 of Set 10 | kyaukse
# Processing Record 7 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 10 | barguzin
# Processing Record 9 of Set 10 | urucara
# Processing Record 10 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 10 | kalemie
# Processing Record 12 of Set 10 | griffith
# Processing Record 13 of Set 10 | kanker
# Processing Record 14 of Set 10 | jiuquan
# Processing Record 15 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 16 of Set 10 | fairbanks
# Processing Record 17 of Set 10 | nisia floresta
# Processing Record 18 of Set 10 | shalinskoye
# Processing Record 19 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 10 | acajutla
# Processing Record 21 of Set 10 | assiniboia
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | dunedin
# Processing Record 24 of Set 10 | linqing
# Processing Record 25 of Set 10 | adrar
# Processing Record 26 of Set 10 | beringovskiy
# Processing Record 27 of Set 10 | san luis
# Processing Record 28 of Set 10 | shkoder
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | znamenskoye
# Processing Record 31 of Set 10 | thaton
# Processing Record 32 of Set 10 | san quintin
# Processing Record 33 of Set 10 | quatre cocos
# Processing Record 34 of Set 10 | woodstock
# Processing Record 35 of Set 10 | talakan
# Processing Record 36 of Set 10 | kannangad
# Processing Record 37 of Set 10 | goderich
# Processing Record 38 of Set 10 | kattivakkam
# Processing Record 39 of Set 10 | hirado
# Processing Record 40 of Set 10 | la ferte-bernard
# Processing Record 41 of Set 10 | lima
# Processing Record 42 of Set 10 | anamur
# Processing Record 43 of Set 10 | kununurra
# Processing Record 44 of Set 10 | college
# Processing Record 45 of Set 10 | chubbuck
# Processing Record 46 of Set 10 | pangody
# Processing Record 47 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 10 | duku
# Processing Record 49 of Set 10 | takab
# Processing Record 50 of Set 10 | lavrentiya
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | guasdualito
# Processing Record 3 of Set 11 | price
# Processing Record 4 of Set 11 | acapulco
# Processing Record 5 of Set 11 | bandarbeyla
# Processing Record 6 of Set 11 | kongolo
# Processing Record 7 of Set 11 | cruz alta
# Processing Record 8 of Set 11 | ilo
# Processing Record 9 of Set 11 | miri
# Processing Record 10 of Set 11 | alugan
# Processing Record 11 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 11 | nanortalik
# Processing Record 13 of Set 11 | port-gentil
# Processing Record 14 of Set 11 | belaya gora
# Processing Record 15 of Set 11 | iquique
# Processing Record 16 of Set 11 | noumea
# Processing Record 17 of Set 11 | san juan
# Processing Record 18 of Set 11 | tandalti
# Processing Record 19 of Set 11 | mezen
# Processing Record 20 of Set 11 | buchanan
# Processing Record 21 of Set 11 | changuinola
# Processing Record 22 of Set 11 | turayf
# Processing Record 23 of Set 11 | lucelia
# Processing Record 24 of Set 11 | ekhabi
# Processing Record 25 of Set 11 | alice springs
# Processing Record 26 of Set 11 | dhidhdhoo
# Processing Record 27 of Set 11 | valdosta
# Processing Record 28 of Set 11 | san policarpo
# Processing Record 29 of Set 11 | dallas
# Processing Record 30 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 11 | senanga
# Processing Record 32 of Set 11 | khor
# Processing Record 33 of Set 11 | camacha
# Processing Record 34 of Set 11 | salme
# Processing Record 35 of Set 11 | omsukchan
# Processing Record 36 of Set 11 | steamboat springs
# Processing Record 37 of Set 11 | kungurtug
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | midland
# Processing Record 40 of Set 11 | nenjiang
# Processing Record 41 of Set 11 | tibiri
# Processing Record 42 of Set 11 | ryotsu
# Processing Record 43 of Set 11 | aksay
# Processing Record 44 of Set 11 | port augusta
# Processing Record 45 of Set 11 | narrabri
# Processing Record 46 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 47 of Set 11 | port hardy
# Processing Record 48 of Set 11 | edd
# Processing Record 49 of Set 11 | ontario
# Processing Record 50 of Set 11 | misratah
# Processing Record 1 of Set 12 | burnie
# Processing Record 2 of Set 12 | youhao
# Processing Record 3 of Set 12 | palmares do sul
# Processing Record 4 of Set 12 | goure
# Processing Record 5 of Set 12 | falkoping
# City not found. Skipping...
# Processing Record 6 of Set 12 | fortuna
# Processing Record 7 of Set 12 | chapais
# Processing Record 8 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 12 | hofn
# Processing Record 11 of Set 12 | kalmunai
# Processing Record 12 of Set 12 | mvuma
# Processing Record 13 of Set 12 | ewa beach
# Processing Record 14 of Set 12 | butembo
# Processing Record 15 of Set 12 | hualmay
# Processing Record 16 of Set 12 | lamar
# Processing Record 17 of Set 12 | toowoomba
# Processing Record 18 of Set 12 | bosaso
# Processing Record 19 of Set 12 | canandaigua
# City not found. Skipping...
# Processing Record 20 of Set 12 | grants pass
# Processing Record 21 of Set 12 | comodoro rivadavia
# Processing Record 22 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | kamina
# Processing Record 24 of Set 12 | san cristobal
# Processing Record 25 of Set 12 | koutiala
# Processing Record 26 of Set 12 | san pedro
# Processing Record 27 of Set 12 | nikki
# Processing Record 28 of Set 12 | seminole
# Processing Record 29 of Set 12 | olinda
# Processing Record 30 of Set 12 | napier
# Processing Record 31 of Set 12 | bamako
# Processing Record 32 of Set 12 | inverell
# Processing Record 33 of Set 12 | san matias
# Processing Record 34 of Set 12 | cape canaveral
# Processing Record 35 of Set 12 | westport
# Processing Record 36 of Set 12 | messina
# Processing Record 37 of Set 12 | mavur
# City not found. Skipping...
# Processing Record 38 of Set 12 | portland
# Processing Record 39 of Set 12 | mokhsogollokh
# Processing Record 40 of Set 12 | luganville
# Processing Record 41 of Set 12 | grand gaube
# Processing Record 42 of Set 12 | hukuntsi
# Processing Record 43 of Set 12 | lagos
# Processing Record 44 of Set 12 | sawakin
# Processing Record 45 of Set 12 | yaan
# Processing Record 46 of Set 12 | puerto madryn
# Processing Record 47 of Set 12 | madaripur
# Processing Record 48 of Set 12 | yarada
# Processing Record 49 of Set 12 | havoysund
# Processing Record 50 of Set 12 | omboue
# Processing Record 1 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 13 | alashtar
# City not found. Skipping...
# Processing Record 3 of Set 13 | moba
# Processing Record 4 of Set 13 | nemuro
# Processing Record 5 of Set 13 | muroto
# Processing Record 6 of Set 13 | veere
# Processing Record 7 of Set 13 | tres arroyos
# Processing Record 8 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 13 | puerto carreno
# Processing Record 10 of Set 13 | harper
# Processing Record 11 of Set 13 | kurilsk
# Processing Record 12 of Set 13 | nezhinka
# Processing Record 13 of Set 13 | neosho
# Processing Record 14 of Set 13 | saint george
# Processing Record 15 of Set 13 | manzhouli
# Processing Record 16 of Set 13 | acolla
# Processing Record 17 of Set 13 | ye
# City not found. Skipping...
# Processing Record 18 of Set 13 | varberg
# Processing Record 19 of Set 13 | bandar-e lengeh
# Processing Record 20 of Set 13 | emerald
# Processing Record 21 of Set 13 | manaus
# Processing Record 22 of Set 13 | grindavik
# Processing Record 23 of Set 13 | bara
# Processing Record 24 of Set 13 | muscat
# Processing Record 25 of Set 13 | songkhla
# Processing Record 26 of Set 13 | kapenguria
# Processing Record 27 of Set 13 | biak
# Processing Record 28 of Set 13 | itarema
# Processing Record 29 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 13 | ciudad guayana
# Processing Record 31 of Set 13 | urumqi
# Processing Record 32 of Set 13 | karratha
# Processing Record 33 of Set 13 | broome
# Processing Record 34 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 35 of Set 13 | ketchikan
# Processing Record 36 of Set 13 | saint anthony
# Processing Record 37 of Set 13 | mayumba
# Processing Record 38 of Set 13 | cooma
# Processing Record 39 of Set 13 | lumeje
# Processing Record 40 of Set 13 | genhe
# Processing Record 41 of Set 13 | mount gambier
# Processing Record 42 of Set 13 | adre
# Processing Record 43 of Set 13 | kumluca
# Processing Record 44 of Set 13 | zanjan
# Processing Record 45 of Set 13 | kurumkan
# Processing Record 46 of Set 13 | kodinsk
# Processing Record 47 of Set 13 | neryungri
# Processing Record 48 of Set 13 | sembe
# Processing Record 49 of Set 13 | lazaro cardenas
# Processing Record 50 of Set 13 | tecoanapa
# Processing Record 1 of Set 14 | aguas formosas
# Processing Record 2 of Set 14 | mojo
# Processing Record 3 of Set 14 | shimoda
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | itaueira
# Processing Record 6 of Set 14 | odemis
# City not found. Skipping...
# Processing Record 7 of Set 14 | doha
# Processing Record 8 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 14 | la peca
# Processing Record 10 of Set 14 | saint-denis
# Processing Record 11 of Set 14 | singleton
# Processing Record 12 of Set 14 | lillebonne
# Processing Record 13 of Set 14 | hauterive
# Processing Record 14 of Set 14 | totma
# Processing Record 15 of Set 14 | miguel calmon
# Processing Record 16 of Set 14 | batagay-alyta
# Processing Record 17 of Set 14 | aykhal
# Processing Record 18 of Set 14 | louga
# Processing Record 19 of Set 14 | kitui
# Processing Record 20 of Set 14 | sisimiut
# Processing Record 21 of Set 14 | starkville
# Processing Record 22 of Set 14 | srandakan
# Processing Record 23 of Set 14 | conceicao do araguaia
# Processing Record 24 of Set 14 | lashio
# Processing Record 25 of Set 14 | kutum
# Processing Record 26 of Set 14 | port hedland
# Processing Record 27 of Set 14 | beboto
# Processing Record 28 of Set 14 | peace river
# Processing Record 29 of Set 14 | sitka
# Processing Record 30 of Set 14 | mugi
# Processing Record 31 of Set 14 | halifax
# Processing Record 32 of Set 14 | benghazi
# Processing Record 33 of Set 14 | prince rupert
# Processing Record 34 of Set 14 | labuhan
# Processing Record 35 of Set 14 | miandrivazo
# Processing Record 36 of Set 14 | harrisonburg
# Processing Record 37 of Set 14 | anguillara sabazia
# Processing Record 38 of Set 14 | cayenne
# Processing Record 39 of Set 14 | mitsamiouli
# Processing Record 40 of Set 14 | aasiaat
# Processing Record 41 of Set 14 | talnakh
# Processing Record 42 of Set 14 | nurota
# Processing Record 43 of Set 14 | muzhi
# Processing Record 44 of Set 14 | biloela
# Processing Record 45 of Set 14 | challans
# Processing Record 46 of Set 14 | prado
# Processing Record 47 of Set 14 | jizan
# Processing Record 48 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 49 of Set 14 | avera
# Processing Record 50 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 15 | vilaka
# Processing Record 2 of Set 15 | abu samrah
# Processing Record 3 of Set 15 | nelson bay
# Processing Record 4 of Set 15 | mahon
# Processing Record 5 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 6 of Set 15 | sovetskiy
# Processing Record 7 of Set 15 | shar
# Processing Record 8 of Set 15 | saint cloud
# Processing Record 9 of Set 15 | los llanos de aridane
# Processing Record 10 of Set 15 | greencastle
# Processing Record 11 of Set 15 | chifeng
# Processing Record 12 of Set 15 | montelimar
# Processing Record 13 of Set 15 | zaraza
# Processing Record 14 of Set 15 | ayagoz
# Processing Record 15 of Set 15 | azare
# Processing Record 16 of Set 15 | tarakan
# Processing Record 17 of Set 15 | powassan
# Processing Record 18 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 15 | dovbysh
# Processing Record 20 of Set 15 | ribas do rio pardo
# Processing Record 21 of Set 15 | norwich
# Processing Record 22 of Set 15 | pahrump
# Processing Record 23 of Set 15 | pio xii
# Processing Record 24 of Set 15 | nizwa
# Processing Record 25 of Set 15 | kegalla
# City not found. Skipping...
# Processing Record 26 of Set 15 | baran
# Processing Record 27 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 15 | burgeo
# Processing Record 29 of Set 15 | nouadhibou
# Processing Record 30 of Set 15 | statesboro
# Processing Record 31 of Set 15 | la ronge
# Processing Record 32 of Set 15 | yuma
# Processing Record 33 of Set 15 | iralaya
# Processing Record 34 of Set 15 | remedios
# Processing Record 35 of Set 15 | watertown
# Processing Record 36 of Set 15 | bay roberts
# Processing Record 37 of Set 15 | auki
# Processing Record 38 of Set 15 | cabinda
# Processing Record 39 of Set 15 | san andres
# Processing Record 40 of Set 15 | vuktyl
# Processing Record 41 of Set 15 | sobolevo
# Processing Record 42 of Set 15 | nizhniy baskunchak
# Processing Record 43 of Set 15 | urubicha
# Processing Record 44 of Set 15 | buin
# Processing Record 45 of Set 15 | muyezerskiy
# Processing Record 46 of Set 15 | tombouctou
# Processing Record 47 of Set 15 | bireun
# Processing Record 48 of Set 15 | sola
# Processing Record 49 of Set 15 | nyurba
# Processing Record 50 of Set 15 | naro-fominsk
# Processing Record 1 of Set 16 | tshela
# Processing Record 2 of Set 16 | tooele
# Processing Record 3 of Set 16 | huilong
# Processing Record 4 of Set 16 | durango
# Processing Record 5 of Set 16 | weiser
# Processing Record 6 of Set 16 | troitsko-pechorsk
# Processing Record 7 of Set 16 | vernon
# Processing Record 8 of Set 16 | shirokiy
# Processing Record 9 of Set 16 | ukiah
# Processing Record 10 of Set 16 | ahmadpur
# Processing Record 11 of Set 16 | buffalo
# Processing Record 12 of Set 16 | shelbyville
# Processing Record 13 of Set 16 | soubre
# Processing Record 14 of Set 16 | mimongo
# Processing Record 15 of Set 16 | ouadda
# Processing Record 16 of Set 16 | thibodaux
# Processing Record 17 of Set 16 | galt
# Processing Record 18 of Set 16 | siavonga
# Processing Record 19 of Set 16 | mwanza
# Processing Record 20 of Set 16 | kharovsk
# Processing Record 21 of Set 16 | miyazu
# Processing Record 22 of Set 16 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity Current Description  \
# 0   Antalaha -14.9003   50.2788     75.54        92          light rain
# 1    Ushuaia -54.8000  -68.3000     50.00        76          few clouds
# 2    Norfolk  42.1668  -71.2495     46.40        34           clear sky
# 3  Nhulunbuy -12.2333  136.7667     84.20        74       broken clouds
# 4   La Rioja  42.2500   -2.5000     57.20        44           clear sky
#
#    Cloudiness  Wind Speed Country                 Date
# 0          80        2.86      MG  2021-03-30 00:20:49
# 1          20        5.75      AR  2021-03-30 00:11:30
# 2           1        6.91      US  2021-03-30 00:19:12
# 3          75       13.80      AU  2021-03-30 00:20:49
# 4           0       12.66      ES  2021-03-30 00:20:50

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
